# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshitha29082006/WPT/blob/main/f17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'First':['Aryan','Rohan','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['Full_tim employee','Intern','Full_time employee','part time employee','Full_time employee'],
    'Department':['Adminstration','Technical','Adminstration','Technical','Technical'],
    'Yoe':[2,3,5,7,6],
    'Salary':[20000,5000,10000,20000, np.nan]

    }
df=pd.DataFrame(data)
print(df)
# Out:
#      First Lastname                Type     Department  Yoe   Salary
# 0    Aryan    Singh   Full_tim employee  Adminstration    2  20000.0
# 1    Rohan  Agarwal              Intern      Technical    3   5000.0
# 2     Riya     Shah  Full_time employee  Adminstration    5  10000.0
# 3     Yash    Batia  part time employee      Technical    7  20000.0
# 4  Siddini     Khan  Full_time employee      Technical    6      NaN
