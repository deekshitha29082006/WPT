# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshitha29082006/WPT/blob/main/f16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
Series_A=pd.Series([10,20,30,40,50])
Series_B=pd.Series([40,50,60,70])
union=pd.Series(np.union1d(Series_A,Series_B))
intersect=pd.Series(np.intersect1d(Series_A,Series_B))
Series_B=pd.Series([40,50,60,70,80])
union=pd.Series(np.union1d(Series_A.values,Series_B.values))
intersect=pd.Series(np.intersect1d(Series_A.values,Series_B.values))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
print("largest number in Series_A is:",Series_A.max())
print("smallest number  in Series_A is:",Series_A.min())
print("the sum of Series_B is:",Series_B.sum())
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64
# largest number in Series_A is: 50
# smallest number  in Series_A is: 10
# the sum of Series_B is: 300
